# %% [markdown]
# 1. Accede a spotify con tu cuenta: https://developer.spotify.com/documentation/web-api
# 2. Ingresa al dashboard con tu cuenta https://developer.spotify.com/dashboard
# 3. Crea una app con una variante del nombre Fundamentos Big Data, explica que es un ejercicio de clase, la URL y URI son las mismas, elige una direccion de pagina web a la que tengas acceso
# 4. Copia el Client ID y Client Secret de la app que acabas de crear
# 5. Instalar la libreria de python para la api de spotify

# %%
#no necesario: pip install typing-extensions==3.10.0.0

# %%
# no necesario: pip install --upgrade spacy

# %% [markdown]
# Necesario instalar:

# %%
#pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#librerias necesarias para la conexion
import requests
import json

# %%
# Ingresa las claves de tu app en el Dashboard de spotify
client_id = "x"
client_secret = "x"

# %%
# Iniciar el cliente de spotify
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Encontrar las mas populares

# %%
# Lista Top 50, encontrar las 10 mas escuchadas
top_tracks = sp.playlist_tracks('37i9dQZEVXbLRQDuF5jeBp', limit=10)

# %%
# Imprimir el nombre de las 10 mas escuchadas
for idx, track in enumerate(top_tracks['items']):
    track_name = track['track']['name']
    artist_name = track['track']['artists'][0]['name']
    print(f"{idx + 1}. {track_name} by {artist_name}")
# Out:
# 1. Yonaguni by Bad Bunny
# 2. Todo De Ti by Rauw Alejandro
# 3. Qué Más Pues? by J Balvin
# 4. ALMAS GEMELAS by Myke Towers
# 5. Sobrio by Maluma
# 6. La Sinvergüenza by Christian Nodal
# 7. 911 (Remix) by Sech
# 8. BICHOTA by KAROL G
# 9. Butter by BTS
# 10. Pareja Del Año by Sebastian Yatra

# %% [markdown]
# ### Encontrar playlists

# %%
# Buscar una playlist por su nombre
playlist_results = sp.search(q='TOP 50 Bolivia', type='playlist')

# %%
playlist_results
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=TOP+50+Bolivia&type=playlist&offset=0&limit=10',
#   'items': [{'collaborative': False,
#     'description': 'The Top 50 tracks in Bolivia right now 🎯 Los 50 mejores éxitos del momento en Bolivia.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3L0GTgyBzx3cITSPBqE5CE'},
#     'href': 'https://api.spotify.com/v1/playlists/3L0GTgyBzx3cITSPBqE5CE',
#     'id': '3L0GTgyBzx3cITSPBqE5CE',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706c0000bebb7b15c2d1a751e939a7c16a66',
#       'width': None}],
#     'name': 'Top 50 Bolivia',
#     'owner': {'display_name': 'kolibrimusic',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/kolibrimusic'},
#      'href': 'https://api.spotify.com/v1/users/kolibrimusic',
#      'id': 'kolibrimusic',
#      'type': 'user',
#      'uri': 'spotify:user:kolibrimusic'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzI0Myw1MDQ0ZWIyMGRhMDA3MWY0MmRmOThiY2ViNzA4ZDVjMzgwMDcxNzll',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3L0GTgyBzx3cITSPBqE5CE/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3L0GTgyBzx3cITSPBqE5CE'},
#    {'collaborative': False,
#     'description': 'Representando la cultura con orgullo. Representing with pride!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcU9MUSqc5Ok'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcU9MUSqc5Ok',
#     'id': '37i9dQZF1DXcU9MUSqc5Ok',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003bbf66925dce32872ecefa71e',
#       'width': None}],
#     'name': 'Made in Bolivia',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY4NjgzNDU1MywwMDAwMDAwMDhlYjMyNzlmMDY4YjRkODliZDMzMjI4YzRhN2NiZTIz',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcU9MUSqc5Ok/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXcU9MUSqc5Ok'},
#    {'collaborative': False,
#     'description': 'LAS 50 MEJORES CANCIONES QUE SUENAN EN BOLIVIA. Foto - Rauw Alejandro, Bizarrap',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0Q96XVlJMaBT798EPUxJBw'},
#     'href': 'https://api.spotify.com/v1/playlists/0Q96XVlJMaBT798EPUxJBw',
#     'id': '0Q96XVlJMaBT798EPUxJBw',
#     'images': [{'height': None,
#       'url': 'https://images-ak.spotifycdn.com/image/ab67706c0000bebb758f189cc71e268b911bedc6',
#       'width': None}],
#     'name': 'Top 50 Bolivia 🇧🇴',
#     'owner': {'display_name': 'Filtr Bolivia',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/i70njzkxhiqhv01720gh1eujm'},
#      'href': 'https://api.spotify.com/v1/users/i70njzkxhiqhv01720gh1eujm',
#      'id': 'i70njzkxhiqhv01720gh1eujm',
#      'type': 'user',
#      'uri': 'spotify:user:i70njzkxhiqhv01720gh1eujm'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTE3NixlMGQ3YjAwOGJhNjNkY2U0YWE1YmM0MGZkYWY4OGI1MWI1OTllNWJl',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0Q96XVlJMaBT798EPUxJBw/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0Q96XVlJMaBT798EPUxJBw'},
#    {'collaborative': False,
#     'description': 'The hottest local and global tracks in Bangladesh. ',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX794NyvTu6nv'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX794NyvTu6nv',
#     'id': '37i9dQZF1DX794NyvTu6nv',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003caed1a720d9903e91d3b352e',
#       'width': None}],
#     'name': 'Hot Hits Bangladesh',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY5MTU2MjM4NSwwMDAwMDAwMDk4YzJhMGZhOWQ1ZTY4YTUzNWJkZTkyNDc0ODRlZDNj',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX794NyvTu6nv/tracks',
#      'total': 70},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX794NyvTu6nv'},
#    {'collaborative': False,
#     'description': 'Your daily update of the most played tracks right now - Bolivia.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZEVXbJqfMFK4d691'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbJqfMFK4d691',
#     'id': '37i9dQZEVXbJqfMFK4d691',
#     'images': [{'height': None,
#       'url': 'https://charts-images.scdn.co/assets/locale_en/regional/daily/region_bo_large.jpg',
#       'width': None}],
#     'name': 'Top 50 - Bolivia',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NzQ0OTMwNjAwLDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDY1NmU=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbJqfMFK4d691/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZEVXbJqfMFK4d691'},
#    {'collaborative': False,
#     'description': 'Los artistas más escuchados del año.\nFoto: Bad Bunny',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4SlZlR1aBak'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4SlZlR1aBak',
#     'id': '37i9dQZF1DX4SlZlR1aBak',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003bf685a3d918e896f54074a57',
#       'width': None}],
#     'name': 'Top Artistas Bolivia 2021',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY4NjgzNTMxOSwwMDAwMDAwMDQzMTg3NmMxN2E3YzhiNjI1ZWNlN2I1MTY5ZDQ4ZjI5',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4SlZlR1aBak/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX4SlZlR1aBak'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2ANglXxQCp2Ma2wAoxbxXQ'},
#     'href': 'https://api.spotify.com/v1/playlists/2ANglXxQCp2Ma2wAoxbxXQ',
#     'id': '2ANglXxQCp2Ma2wAoxbxXQ',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b27315583045b2fdb7d7bab10e81ab67616d0000b27357ed58cb724f8d55f78a1d4cab67616d0000b273716c0b0ad51594ff788b5f06ab67616d0000b273fc9ce77ab8fcd9eadda3acd3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b27315583045b2fdb7d7bab10e81ab67616d0000b27357ed58cb724f8d55f78a1d4cab67616d0000b273716c0b0ad51594ff788b5f06ab67616d0000b273fc9ce77ab8fcd9eadda3acd3',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b27315583045b2fdb7d7bab10e81ab67616d0000b27357ed58cb724f8d55f78a1d4cab67616d0000b273716c0b0ad51594ff788b5f06ab67616d0000b273fc9ce77ab8fcd9eadda3acd3',
#       'width': 60}],
#     'name': 'Top 50 Bolivia',
#     'owner': {'display_name': 'Carlos Roca Charly Rock',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/ymkh3xmcbffu3d2pooebgxhgy'},
#      'href': 'https://api.spotify.com/v1/users/ymkh3xmcbffu3d2pooebgxhgy',
#      'id': 'ymkh3xmcbffu3d2pooebgxhgy',
#      'type': 'user',
#      'uri': 'spotify:user:ymkh3xmcbffu3d2pooebgxhgy'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NTMsYTc2OTEwZDhjMGQyMmVhM2Q4MDFkZjM0MjYwZDRmYzAzYjM5YjI3OA==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2ANglXxQCp2Ma2wAoxbxXQ/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2ANglXxQCp2Ma2wAoxbxXQ'},
#    {'collaborative': False,
#     'description': 'This is Bolibompa. The essential tracks, all in one playlist.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DZ06evNZZTZEE'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evNZZTZEE',
#     'id': '37i9dQZF1DZ06evNZZTZEE',
#     'images': [{'height': None,
#       'url': 'https://thisis-images.scdn.co/37i9dQZF1DZ06evNZZTZEE-large.jpg',
#       'width': None}],
#     'name': 'This Is Bolibompa',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjgxOTMwNjcsMDAwMDAwMDA1OTFjYmU2ZmNlYWM3NThmMjM2NTg0ZmZmNzU1ZWZkZg==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evNZZTZEE/tracks',
#      'total': 30},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DZ06evNZZTZEE'},
#    {'collaborative': False,
#     'description': 'Your daily update of the most viral tracks right now - Bolivia.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZEVXbMTKZuy8ORFV'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMTKZuy8ORFV',
#     'id': '37i9dQZEVXbMTKZuy8ORFV',
#     'images': [{'height': None,
#       'url': 'https://charts-images.scdn.co/assets/locale_en/viral/daily/region_bo_large.jpg',
#       'width': None}],
#     'name': 'Viral 50 - Bolivia',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NzQ0OTMwNjAwLDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDY1NmU=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMTKZuy8ORFV/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZEVXbMTKZuy8ORFV'},
#    {'collaborative': False,
#     'description': '¡Escucha los éxitos de hoy!\nFoto: Grupo Frontera',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXbOnyEG5dOWL'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXbOnyEG5dOWL',
#     'id': '37i9dQZF1DXbOnyEG5dOWL',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003d7ab1df1a040fdb31adda1fc',
#       'width': None}],
#     'name': 'Éxitos Bolivia',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY5MTA5NDA5MSwwMDAwMDAwMDY4MmJjYzk1MjYzYzg5OGM2NmJhNDRjYWNhZDgzMGY0',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXbOnyEG5dOWL/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXbOnyEG5dOWL'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=TOP+50+Bolivia&type=playlist&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 53}}

# %%
# Extraer los IDs de las playlists  y las descripciones
if playlist_results and 'playlists' in playlist_results:
    playlists = playlist_results['playlists']['items']
    if playlists:
        playlist_id = playlists[5]['id']
        print(f"Playlist ID: {playlist_id}")
    else:
        print("No playlists found with that name.")
else:
    print("No playlist search results.")
# Out:
# Playlist ID: 37i9dQZF1DX4SlZlR1aBak

# %%
playlist_name = 'Mapreduce'
playlist_results = sp.search(q=playlist_name, type='playlist')

# %%
if playlist_results and 'playlists' in playlist_results:
    playlists = playlist_results['playlists']['items']
    if playlists:
        print(f"Found {len(playlists)} playlists with the name '{playlist_name}':")
        for idx, playlist in enumerate(playlists):
            playlist_id = playlist['id']
            playlist_description = playlist['description']
            print(f"Playlist {idx + 1} ID: {playlist_id}")
            print(f"Description: {playlist_description}\n")
    else:
        print("No playlists found with that name.")
else:
    print("No playlist search results.")
# Out:
# Found 10 playlists with the name 'Mapreduce':
# Playlist 1 ID: 37i9dQZF1DWYXEO3u0YOMv
# Description: 設立10周年を迎えた<a href="http://www.mappa.co.jp/">MAPPA</a>作品の音楽をひとつのプレイリストに。Listen to the songs from 30+ anime shows MAPPA has produced in the last decade of its history!
#
# Playlist 2 ID: 37i9dQZF1DZ06evO3aR8u4
# Description: This is Mapache. The essential tracks, all in one playlist.
#
# Playlist 3 ID: 37i9dQZF1DZ06evO2FubyV
# Description: This is MAPESS. The essential tracks, all in one playlist.
#
# Playlist 4 ID: 37i9dQZF1DZ06evO09ehvr
# Description: This is DJ Maphorisa. The essential tracks, all in one playlist.
#
# Playlist 5 ID: 37i9dQZF1DZ06evO30hQWf
# Description: This is Maps & Atlases. The essential tracks, all in one playlist.
#
# Playlist 6 ID: 37i9dQZF1DZ06evO19LO9j
# Description: This is Mapaputsi. The essential tracks, all in one playlist.
#
# Playlist 7 ID: 37i9dQZF1DZ06evO1U6qid
# Description: This is Maps. The essential tracks, all in one playlist.
#
# Playlist 8 ID: 37i9dQZF1DZ06evO3E5gME
# Description: This is Mapei. The essential tracks, all in one playlist.
#
# Playlist 9 ID: 37i9dQZF1DZ06evNZZUONH
# Description: This is Mapara A Jazz. The essential tracks, all in one playlist.
#
# Playlist 10 ID: 37i9dQZF1DZ06evNZWJ5Fv
# Description: This is Mapa. The essential tracks, all in one playlist.

# %% [markdown]
# #### Describir canciones

# %%
# Search for tracks by name
track_name = 'Me cuesta tanto olvidarte'
track_results = sp.search(q=track_name, type='track', limit=10)

# Extract the duration and artist from the search results
if track_results and 'tracks' in track_results:
    tracks = track_results['tracks']['items']
    if tracks:
        print(f"Found {len(tracks)} tracks with the name '{track_name}':")
        for idx, track in enumerate(tracks):
            track_name = track['name']
            track_duration = track['duration_ms']  # Duration in milliseconds
            track_artist = track['artists'][0]['name']
            
            # Convert duration from milliseconds to minutes and seconds
            duration_minutes = track_duration // 60000
            duration_seconds = (track_duration % 60000) // 1000
            
            print(f"Track {idx + 1} - {track_name}")
            print(f"Artist: {track_artist}")
            print(f"Duration: {duration_minutes}:{duration_seconds:02}\n")
    else:
        print("No tracks found with that name.")
else:
    print("No track search results.")
# Out:
# Found 10 tracks with the name 'Me cuesta tanto olvidarte':
# Track 1 - Me cuesta tanto olvidarte
# Artist: Mecano
# Duration: 2:54
#
# Track 2 - Me Cuesta Tanto Olvidarte
# Artist: Los Ángeles Azules
# Duration: 2:44
#
# Track 3 - Me Cuesta Tanto Olvidarte
# Artist: Enrique Iglesias
# Duration: 3:34
#
# Track 4 - Llorando Bajo La Lluvia
# Artist: Bronco
# Duration: 3:14
#
# Track 5 - Me Cuesta Tanto Olvidarte
# Artist: Claire Delić
# Duration: 3:43
#
# Track 6 - Me Cuesta Tanto
# Artist: Los inquietos del vallenato
# Duration: 4:33
#
# Track 7 - Me Cuesta Tanto Olvidarte
# Artist: Thalia
# Duration: 3:22
#
# Track 8 - Me cuesta tanto olvidarte
# Artist: Alex Ubago
# Duration: 2:27
#
# Track 9 - Me Cuesta Olvidarla
# Artist: Skavy El Ángel Caído
# Duration: 3:12
#
# Track 10 - Me Cuesta Tanto Olvidarte
# Artist: Tommy Torres
# Duration: 3:25

# %% [markdown]
# #### Buscar las canciones de un artista

# %%
# Search for the artist by name
artist_name = 'Macano'
artist_results = sp.search(q=artist_name, type='artist', limit=1)

# Extract the artist's ID from the search results
if artist_results and 'artists' in artist_results:
    artists = artist_results['artists']['items']
    if artists:
        artist_id = artists[0]['id']
        
        # Get the artist's albums
        artist_albums = sp.artist_albums(artist_id, album_type='album')
        
        # Extract and print the names of the artist's albums
        print(f"Albums by {artist_name}:")
        for album in artist_albums['items']:
            print(album['name'])
            
            # Get the tracks of each album
            album_tracks = sp.album_tracks(album['id'])
            
            # Print the tracks of the album
            for track in album_tracks['items']:
                print(f"  {track['name']}")
    else:
        print("No artists found with that name.")
else:
    print("No artist search results.")
# Out:
# Albums by Macano:
# Esencial Mecano
#   Hoy no me puedo levantar
#   Cruz de navajas
#   Japon
#   No es serio este cementerio
#   Ay, qué pesado
#   Hijo de la luna
#   Los Amantes
#   No hay marcha en Nueva York
#   Barco a Venus
#   Me cuesta tanto olvidarte
#   Aire
#   J.C.
#   Me Colé en una Fiesta
#   Hawaii-Bombay
#   Maquillaje
#   "Eungenio" Salvador Dalí
#   La Fuerza del Destino
#   Dalai Lama
#   Naturaleza Muerta
#   El 7 de Septiembre
#   Tu
#   El Fallo Positivo
#   Una rosa es una rosa
#   El Uno, el Dos, el Tres
#   Heroes de la Antartida
#   Cuerpo y Corazón
#   El Club de los Humildes
#   Otro Muerto
#   Stereosexual
#   Un Año Mas
# Siglo XXI
#   Hoy no me puedo levantar
#   Me Colé en una Fiesta
#   Maquillaje
#   Perdido en mi habitacion
#   Barco a Venus
#   Japon
#   Hawaii-Bombay
#   La estacion
#   Aire
#   Cruz de navajas
#   No es serio este cementerio
#   Me cuesta tanto olvidarte
#   Hijo de la luna
#   No hay marcha en Nueva York
#   Los Amantes
#   Mujer contra mujer
#   Un Año Mas
#   La Fuerza del Destino
#   "Eungenio" Salvador Dalí
#   El Cine
#   Quedate en Madrid
#   El 7 de Septiembre
#   Naturaleza Muerta
#   Dalai Lama
#   Una rosa es una rosa
#   El Fallo Positivo
#   Bailando Salsa
#   El Uno, el Dos, el Tres
#   Stereosexual
#   Cuerpo y Corazón
#   Maria Luz
#   Un Año Mas - Pedro Del Moral, John Jacobsen, Kung Foo & Anzwer Remix
#   La Fuerza del Destino - Catcomplex & Sidechains Remix
# Ana, José, Nacho
#   Une femme avec une femme
#   Dis moi lune d'argent
#   Dalai Lama
#   No hay marcha en Nueva York
#   Le Club des Modestes
#   Otro Muerto
#   Toi
#   Une histoire a trois
#   Corps et coeur
#   Le 7 Septembre
#   Stereosexual
#   Ésto No Es una Canción
#   El Mundo Futuro
#   Los Piratas del Amor
#   El Blues del Esclavo - Version Tango
#   Frere Soleil, Soeur Lune
#   Aire
# Ana, José, Nacho
#   Cuerpo y Corazón
#   Otro Muerto
#   El Club de los Humildes
#   Aire
#   Un Año Mas
#   Naturaleza Muerta
#   Hoy no me puedo levantar
#   "Eungenio" Salvador Dalí
#   El 7 de Septiembre
#   Me cuesta tanto olvidarte
#   La Fuerza del Destino
#   No es serio este cementerio
#   "Hermano Sol, Hermana Luna"
#   Una rosa es una rosa
#   Maquillaje
#   Hijo de la luna
#   Stereosexual
#   El Mundo Futuro
#   Ésto No Es una Canción
#   Los Piratas del Amor
#   El Uno, el Dos, el Tres
#   Barco a Venus
#   Cruz de navajas
#   Ay, qué pesado
#   No hay marcha en Nueva York
#   Perdido en mi habitacion
#   Hawaii-Bombay
#   Dalai Lama
#   Mujer contra mujer
#   Me Colé en una Fiesta
# Aidalai (Bonus Track Edition)
#   El Fallo Positivo
#   El Uno, el Dos, el Tres
#   Bailando Salsa
#   El 7 de Septiembre
#   Naturaleza Muerta
#   1917
#   Una rosa es una rosa
#   El Lago Artificial
#   Tu
#   Dalai Lama
#   El Peón del Rey de Negras
#   J.C.
#   Sentía
#   El 7 de Septiembre - Versión Acustica
# Aidalai
#   Dis moi lune d'argent
#   El Fallo Positivo
#   Une histoire a trois
#   J.C.
#   Bailando Salsa
#   Dalai Lama
#   Toi
#   Le 7 Septembre
#   Una rosa es una rosa
#   Le paradis artificiel
#   Nature Morte
#   1917
#   El Peón del Rey de Negras
#   Sentía
# Descanso Dominical / Une Femme Avec Une Femme
#   Hijo de la luna
#   La Fuerza del Destino - Live
#   El Blues del Esclavo - Version Tango
#   Los Amantes
#   Mujer contra mujer
#   Por la Cara
#   Une femme avec une femme
#   No Hay Marcha en Nueva York - Live
#   El Cine
#   "Eungenio" Salvador Dalí
#   Un Año Mas
#   Quedate en Madrid
# Descanso Dominical (Bonus Tracks Edition)
#   El Cine
#   No hay marcha en Nueva York
#   Mujer contra mujer
#   Los Amantes
#   La Fuerza del Destino
#   Quedate en Madrid
#   Laika
#   El Blues del Esclavo - Version Tango
#   "Eungenio" Salvador Dalí
#   Por la Cara
#   Un Año Mas
#   Heroes de la Antartida
#   "Hermano Sol, Hermana Luna"
#   Fabula
#   Une femme avec une femme
# Mecano
#   Hoy no me puedo levantar
#   No Me Enseñen la Lección
#   Perdido en mi habitacion
#   Cenando en Paris
#   Maquillaje
#   Boda en Londres
#   Me Colé en una Fiesta
#   La Máquina de Vapor
#   Me Voy de Casa
#   254.13.26
#   El Fin del Mundo
#   Sólo Soy una Persona
#   Quiero Vivir en la Ciudad
# Entre el Cielo y el Suelo (Bonus Tracks Edition)
#   Ay, qué pesado
#   Ángel
#   Hijo de la luna
#   50 palabras, 60 palabras o 100
#   Te busqué
#   Me cuesta tanto olvidarte
#   No tienes nada que perder
#   Las curvas de esa chica
#   No es serio este cementerio
#   Cruz de navajas
#   Las cosas pares
#   Esta es la historia de un amor
#   Canción Cortita para Antes Que Nos Abandone el Mar
#   Figlio de la luna
# En Concierto (Live)
#   Japón - Live
#   Hoy no Me Puedo Levantar - Live
#   Quiero Vivir en la Ciudad - Live
#   Aire - Live
#   Me Colé en una Fiesta - Live
#   Hawaii-Bombay - Live
#   Ya Viene el Sol - Live
#   La Estación - Live
#   El Amante de Fuego - Live
#   Barco a Venus - Live
#   Maquillaje - Live
#   Me Voy de Casa - Live
# Ya Viene el Sol (Bonus Tracks Edition)
#   No pintamos nada
#   Ya viene el sol
#   La estacion
#   Hawaii-Bombay
#   Mosquito
#   Busco algo barato
#   Aire
#   Me Rio de Janeiro
#   Japon
#   El mapa de tu corazon
#   Hawaii-Bombay - Remix
# ¿Dónde Está el Pais de las Hadas? (Bonus Tracks Edition)
#   ¿Dónde Está el Pais de las Hadas?
#   Este Chico Es una Joya
#   La Bola de Cristal
#   El Amante de Fuego
#   Madrid
#   Barco a Venus
#   La Fiesta Nacional
#   Un Poco Loco
#   No Aguanto Más
#   Focas
#   El Balón
#   El Ladrón de Discos
#   Viaje Espacial
