# %% [markdown]
# ### Libreria de Procesamiento de Lenguaje Natural

# %%
import nltk
nltk.download('cess_esp')
#usersharon836
# Out:
# [nltk_data] Downloading package cess_esp to
# [nltk_data]     C:\Users\nicol\AppData\Roaming\nltk_data...
# [nltk_data]   Package cess_esp is already up-to-date!
# True

# %% [markdown]
# Fuente: https://melaniewalsh.github.io/Intro-Cultural-Analytics/05-Text-Analysis/Multilingual/Spanish/03-POS-Keywords-Spanish.html
#
#     Instalar la linea inferior solo una vez

# %%
# !pip install -U spacy

# %% [markdown]
# #### Paso Final POS - Ejemplo español

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
pd.set_option("max_rows", 400)
pd.set_option("max_colwidth", 400)

#modulo para español:
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# c:\Users\nicol\Documents\DATA_SCIENCE_UPB_TASKS\02 HW Code\020Procesamiento de lenguaje natural.ipynb Cell 6 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/nicol/Documents/DATA_SCIENCE_UPB_TASKS/02%20HW%20Code/020Procesamiento%20de%20lenguaje%20natural.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> from collections import Counter
#       <a href='vscode-notebook-cell:/c%3A/Users/nicol/Documents/DATA_SCIENCE_UPB_TASKS/02%20HW%20Code/020Procesamiento%20de%20lenguaje%20natural.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nicol/Documents/DATA_SCIENCE_UPB_TASKS/02%20HW%20Code/020Procesamiento%20de%20lenguaje%20natural.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> pd.set_option("max_rows", 400)
#       <a href='vscode-notebook-cell:/c%3A/Users/nicol/Documents/DATA_SCIENCE_UPB_TASKS/02%20HW%20Code/020Procesamiento%20de%20lenguaje%20natural.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> pd.set_option("max_colwidth", 400)
#       <a href='vscode-notebook-cell:/c%3A/Users/nicol/Documents/DATA_SCIENCE_UPB_TASKS/02%20HW%20Code/020Procesamiento%20de%20lenguaje%20natural.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> #modulo para español:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_config\config.py:264, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     263 def __call__(self, *args, **kwds) -> T:
# --> 264     return self.__func__(*args, **kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_config\config.py:157, in _set_option(*args, **kwargs)
#     154     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     156 for k, v in zip(args[::2], args[1::2]):
# --> 157     key = _get_single_key(k, silent)
#     159     o = _get_registered_option(key)
#     160     if o and o.validator:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_config\config.py:124, in _get_single_key(pat, silent)
#     122     raise OptionError(f"No such keys(s): {repr(pat)}")
#     123 if len(keys) > 1:
# --> 124     raise OptionError("Pattern matched multiple keys")
#     125 key = keys[0]
#     127 if not silent:
#
# OptionError: Pattern matched multiple keys

# %%
 # !python -m spacy download es_core_news_md
# Out:
# Collecting es-core-news-md==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news
MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------  42.3/42.3 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------------- 42.3/42.3 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from es-core-news-md==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (1.23.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (2.4.0)
# Requirement already satisfied: jinja2 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (0.5.0)
# Requirement already satisfied: pydantic-core==2.10.0 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (2.10.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (0.1.3)
# Requirement already satisfied: colorama in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nicol\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2->spacy<3.7.0,>=3.6.0->es-core-news-md==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_md')

# %%
nlp = spacy.load('es_core_news_md')

# %%
text = "Quisiera un refresco de manzana."

# %%
# create spacy 
doc = nlp(text)
for token in doc:
    print(token.text,'->',token.pos_)
# Out:
# Quisiera -> VERB
# un -> DET
# refresco -> NOUN
# de -> ADP
# manzana -> NOUN
# . -> PUNCT

# %% [markdown]
# ## Pipeline del Procesamiento de Lenguaje Natural

# %% [markdown]
# #### Libreria NLTK

# %%
 import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.parse import DependencyGraph
from nltk import pos_tag

# Download NLTK data (if not done before)
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nicol\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nicol\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# El texto

# %%
text = "I love this pretty dog. Besides, its owner is from Bolivia"

# %% [markdown]
# 1. Sentence Segmentation

# %%
sentences = sent_tokenize(text)
print("Sentence Segmentation:")
print(sentences)
# Out:
# Sentence Segmentation:
# ['I love this pretty dog.', 'Besides, its owner is from Bolivia']

# %% [markdown]
# 2. Word Tokenization

# %%
words = word_tokenize(text)
print("\nWord Tokenization:")
print(words)
# Out:
# Word Tokenization:
# ['I', 'love', 'this', 'pretty', 'dog', '.', 'Besides', ',', 'its', 'owner', 'is', 'from', 'Bolivia']

# %% [markdown]
# 3. Stemming - Encontrar la raíz

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in words]
print("\nStemming:")
print(stemmed_words)
# Out:
# Stemming:
# ['i', 'love', 'thi', 'pretti', 'dog', '.', 'besid', ',', 'it', 'owner', 'is', 'from', 'bolivia']

# %% [markdown]
# Lematizador

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nicol\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
print("\nLemmatization:")
print(lemmatized_words)
# Out:
# Lemmatization:
# ['I', 'love', 'this', 'pretty', 'dog', '.', 'Besides', ',', 'it', 'owner', 'is', 'from', 'Bolivia']

# %% [markdown]
# 5. Stop Word Analysis: identificar y eliminar palabras prescindibles de un texto.

# %%
#Las palabras vacías son palabras de uso común que generalmente se consideran de poco valor.
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words]
print("\nStop Word Analysis:")
print(filtered_words)
# Out:
# Stop Word Analysis:
# ['love', 'pretty', 'dog', '.', 'Besides', ',', 'owner', 'Bolivia']

# %% [markdown]
# 6. y 7. Parsing de dependencia y speech tagging

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\nicol\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
pos_tags = pos_tag(filtered_words)
print("\nPart of Speech Tagging:")
print(pos_tags)
# Out:
# Part of Speech Tagging:
# [('love', 'VB'), ('pretty', 'RB'), ('dog', 'NN'), ('.', '.'), ('Besides', 'NNP'), (',', ','), ('owner', 'NN'), ('Bolivia', 'NNP')]

# %%
#fuente para el codigo del grafico> https://www.analyticsvidhya.com/blog/2020/06/nlp-project-information-extraction/
#useful datasets> https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/0TJX8Y
from spacy import displacy 
displacy.render(doc, style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="bc0c84b7082c44c8b962eb06eeb915c1-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Quisiera</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">un</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">refresco</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">manzana.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bc0c84b7082c44c8b962eb06eeb915c1-0-0" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bc0c84b7082c44c8b962eb06eeb915c1-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bc0c84b7082c44c8b962eb06eeb915c1-0-1" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bc0c84b7082c44c8b962eb06eeb915c1-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,179.0 L408.0,167.0 392.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bc0c84b7082c44c8b962eb06eeb915c1-0-2" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bc0c84b7082c44c8b962eb06eeb915c1-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bc0c84b7082c44c8b962eb06eeb915c1-0-3" stroke-width="2px" d="M420,177.0 C420,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bc0c84b7082c44c8b962eb06eeb915c1-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,179.0 L758.0,167.0 742.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Manipulacion de oraciones

# %%
txt1 = ['Necesito un bowl de acai porfavor.',
 'Me da un jugo de tumbo?',
 'Vendame dos hamburguesas de barbacoa.',
 'voy a llevar una hamburguesa mediana con papas.',
 'A mí me gustaría la ensalada César.',
 'para empezar, voy a pedir la sopa de tomate.',
 'Para el postre quiero una torta de durazno',
 'Para beber, una sangría, por favor.',
 'De primero tomaremos la crema de verduras y una ensalada mixta.',
 'Probaremos el arroz con leche y la tarta de chocolate.',
 'Tomaré una cerveza, por favor.',
 '¿Me da un postre de canela?','Deme un pollo frito con curry.',
 'Me trae una pizza de palmito',
 'Deme tres trancapechos',
 'Deme una chuleta de carne con huevo',
 'Deme tres tacos con jalapenios',
 'Traigame cinco pizzas con jamon y tomate',
 'Quiero 6 pollos personales',
 'Quisiera tres hamburguesas con pepino',
 'Me trae papas fritas',
 'vendame cinco empanadas de pollo',
 'Llevaré tres sandwich de palta',
 'Necesito una pasta de albahaca',
      'Quiero llevar 2 pizzas con piña']

# %%
doc = nlp(txt1[1])
for token in doc:
    print(token.text,token.pos_,token.dep_)
# Out:
# Me PRON iobj
# da VERB ROOT
# un DET det
# jugo NOUN nsubj
# de ADP case
# tumbo NOUN nmod
# ? PUNCT punct

# %%
from spacy import displacy 
displacy.render(doc, style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="06676e7fd6064ed5b531e39472a948cb-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Me</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">da</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">un</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">jugo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">tumbo?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-06676e7fd6064ed5b531e39472a948cb-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-06676e7fd6064ed5b531e39472a948cb-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">iobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-06676e7fd6064ed5b531e39472a948cb-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-06676e7fd6064ed5b531e39472a948cb-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-06676e7fd6064ed5b531e39472a948cb-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-06676e7fd6064ed5b531e39472a948cb-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-06676e7fd6064ed5b531e39472a948cb-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-06676e7fd6064ed5b531e39472a948cb-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-06676e7fd6064ed5b531e39472a948cb-0-4" stroke-width="2px" d="M595,177.0 C595,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-06676e7fd6064ed5b531e39472a948cb-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
doc = nlp(txt1[14])
for token in doc:
    print(token.text,token.pos_,token.dep_)
# Out:
# Deme PROPN ROOT
# tres NUM nummod
# trancapechos NOUN obj

# %%
from spacy import displacy 
displacy.render(doc, style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="a54579f83c894307b1a3207f618336c9-0" class="displacy" width="575" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Deme</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">tres</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">trancapechos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a54579f83c894307b1a3207f618336c9-0-0" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a54579f83c894307b1a3207f618336c9-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a54579f83c894307b1a3207f618336c9-0-1" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a54579f83c894307b1a3207f618336c9-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,179.0 L408.0,167.0 392.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>
